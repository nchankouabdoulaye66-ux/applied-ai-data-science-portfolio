# %% [markdown]
# # FoodHub Order Data Analysis
#
# This notebook presents an exploratory data analysis project on food delivery orders.
#
# ## Goal
# Use Python to analyze orders, restaurant performance, cuisine preferences, delivery time, order cost, customer ratings, and business recommendations.
#
# > Note: This public portfolio version removes course grading text, local file paths, and execution outputs. Add the dataset separately under `data/foodhub_order.csv` if you want to run it.

# %% [markdown]
# ### Context
#
# The number of restaurants in New York is increasing day by day. Lots of students and busy professionals rely on those restaurants due to their hectic lifestyles. Online food delivery service is a great option for them. It provides them with good food from their favorite restaurants. A food aggregator company FoodHub offers access to multiple restaurants through a single smartphone app.
#
# The app allows the restaurants to receive a direct online order from a customer. The app assigns a delivery person from the company to pick up the order after it is confirmed by the restaurant. The delivery person then uses the map to reach the restaurant and waits for the food package. Once the food package is handed over to the delivery person, he/she confirms the pick-up in the app and travels to the customer's location to deliver the food. The delivery person confirms the drop-off in the app after delivering the food package to the customer. The customer can rate the order in the app. The food aggregator earns money by collecting a fixed margin of the delivery order from the restaurants.
#
# ### Objective
#
# The food aggregator company has stored the data of the different orders made by the registered customers in their online portal. They want to analyze the data to get a fair idea about the demand of different restaurants which will help them in enhancing their customer experience. Suppose you are hired as a Data Scientist in this company and the Data Science team has shared some of the key questions that need to be answered. Perform the data analysis to find answers to these questions that will help the company to improve the business.
#
# ### Data Description
#
# The data contains the different data related to a food order. The detailed data dictionary is given below.
#
# ### Data Dictionary
#
# * order_id: Unique ID of the order
# * customer_id: ID of the customer who ordered the food
# * restaurant_name: Name of the restaurant
# * cuisine_type: Cuisine ordered by the customer
# * cost: Cost of the order
# * day_of_the_week: Indicates whether the order is placed on a weekday or weekend (The weekday is from Monday to Friday and the weekend is Saturday and Sunday)
# * rating: Rating given by the customer out of 5
# * food_preparation_time: Time (in minutes) taken by the restaurant to prepare the food. This is calculated by taking the difference between the timestamps of the restaurant's order confirmation and the delivery person's pick-up confirmation.
# * delivery_time: Time (in minutes) taken by the delivery person to deliver the food package. This is calculated by taking the difference between the timestamps of the delivery person's pick-up confirmation and drop-off information

# %% [markdown]
# ### Let us start by importing the required libraries

# %%
# import libraries for data manipulation
import numpy as np
import pandas as pd

# import libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Understanding the structure of the data

# %%
# If running in Google Colab, upload the dataset to the data/ folder or mount Google Drive manually.

# %%
df=pd.read_csv('data/foodhub_order.csv')
df.head()

# %%
path='data/'
df=pd.read_csv(path + 'foodhub_order.csv')
df.head()

# %%
import os
os.listdir('data/')

# %% [markdown]
# #### Observations:
#
# The DataFrame has 9 columns as mentioned in the Data Dictionary. Data in each row corresponds to the order placed by a customer.

# %% [markdown]
# ### Analysis Question 1:** How many rows and columns are present in the data?

# %%
df.shape

# %% [markdown]
# #### Observations:
# The dataset contains 1898 rows and 9 columns. Each rows represents a food order placed by a costumer, and each column represents a variable describing the order.

# %% [markdown]
# ### Analysis Question 2:** What are the datatypes of the different columns in the dataset? (The info() function can be used)

# %%
df.info()

# %% [markdown]
# #### Observations:
# The dataset contains both numerical and categorical variables.
# Numerical variables include order_id, customer_id, cost_of_the_order, food_preparation_time, and delivery_time.
# Categorical variables include restaurant_name, cuisine_type, day_of_the_week, and rating

# %% [markdown]
# ### Analysis Question 3:** Are there any missing values in the data? If yes, treat them using an appropriate method.

# %%
# Check missing values
df.isnull().sum()

# %% [markdown]
# #### Observations:
# There are no missing values in the dataset, as all columns contain complete observations. Therefore, no data imputation or treatment is required

# %% [markdown]
# ### Analysis Question 4:** Check the statistical summary of the data. What is the minimum, average, and maximum time it takes for food to be prepared once an order is placed?

# %%
df['food_preparation_time'].describe()

# %% [markdown]
# #### Observations:
# The minimum food preparation time is 20 minutes, while the maximun preparation time is 35 minutes. On average, restaurants take approximately 27 minutes to prepare an order.

# %% [markdown]
# ### Analysis Question 5:** How many orders are not rated?

# %%
df[df['rating']=='Not given'].shape[0]

# %% [markdown]
# #### Observations:
# Out of 1898 orders, 736 orders were not rated by customers. This indicates that a significant portion of customers did not provide feedback for thier orders, which may limit the ability to analyze customer satisfaction accurately.

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# ### Analysis Question 6:** Explore all the variables and provide observations on their distributions. (Generally, histograms, boxplots, countplots, etc. are used for univariate exploration.)

# %% [markdown]
# Distribution of order cost

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['cost_of_the_order'], bins=30)
plt.title('Distribution of Order Cost')
plt.savefig("graph_order_cost.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Observations:
#
# The distribution of order cost show that most orders fall within a moderate price range, with fewer orders at higher prices.

# %% [markdown]
# Ratings

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='rating', data=df)
plt.title('Distribution of Ratings')
plt.savefig("graph_ratings.jpg", bbox_inches='tight')
plt.show

# %% [markdown]
# Observations:
#
# Most ratings are 4 or 5, indicating generally high customer satisfaction. A significant number of orders have no rating provided.

# %% [markdown]
# Cuisine types

# %%
plt.figure(figsize=(10,5))
df['cuisine_type'].value_counts().plot(kind='bar')
plt.title('Number of Orders by Cuisine Type')
plt.xticks(rotation=90)
plt.savefig("graph_cuisine_type.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Observations:
#
# Some cuisine types are significantly more popular than others, indicating customer preference for certain types of food.

# %% [markdown]
# Delivery day

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='day_of_the_week', data=df)
plt.title('Orders by Day Type')
plt.savefig("graph_day_of_the_week.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Observations:
#
# Orders appear to be distributed between weekdays and weekends, showing that customers use the platform throughout the week.

# %% [markdown]
# Food preparation times

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['food_preparation_time'], bins=20)
plt.title('Food Preparation Time Distribution')
plt.savefig("graph_food_preparation_time.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Observations:
#
# Food preparation times appear concentrated around the average value, suggesting most restaurants have similar preparation time.

# %% [markdown]
# Delivery times

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['delivery_time'], bins=20)
plt.title('Delivery Time Distribution')
plt.savefig("graph_delivery_time.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Observations:
#
# Delivery times are relatively concentrated within a certain range, indicating consistent delivery performance.

# %% [markdown]
# Boxplot to detect extreme values (cost)

# %%
plt.figure(figsize=(6,4))
sns.boxplot(x=df['cost_of_the_order'])
plt.title('Boxplot of Order Cost')
plt.savefig("graph_boxplot_cost.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Observations:
#
# The boxplot suggests that while most orders fall within a moderate price range, there are a few higher-cost outliers.

# %% [markdown]
# ### Analysis Question 7**: Which are the top 5 restaurants in terms of the number of orders received?

# %%
df['restaurant_name'].value_counts().head(5)

# %% [markdown]
# #### Observations:
# The restaurants receiving the highest number of orders are Shake Shack, The Meatball Shop, Blue Ribbon Sushi, Blue Ribbon Fried Chicken, and Parm, Among them, Shake Shack has the highest number of orders, indicating strong customer preference.

# %% [markdown]
# ### Analysis Question 8**: Which is the most popular cuisine on weekends?

# %%
df[df['day_of_the_week']=='Weekend']['cuisine_type'].value_counts().head(1)

# %% [markdown]
# #### Observations:
# The most popular cuisine on weekends is American cuisine, indicating that customers tend to prefer American food when ordering during weekends.

# %% [markdown]
# ### Analysis Question 9**: What percentage of the orders cost more than 20 dollars?

# %%
# Total number of orders
total_orders = df.shape[0]

# Orders costing more than $20
orders_above_20 = df[df['cost_of_the_order'] > 20].shape[0]

# Percentage
Percentage = (orders_above_20 / total_orders) * 100

Percentage

# %% [markdown]
# #### Observations:
# Approximately 29.24% of the orders cost more than $20, indicating that a significant portion of customers place reletively higher-value orders.

# %% [markdown]
# ### Analysis Question 10**: What is the mean order delivery time?

# %%
df['delivery_time'].mean()

# %% [markdown]
# #### Observations:
# The mean order delivery time is approximately 24.16 minutes, indicating that most deliveries are completed within about 24 minutes on average.

# %% [markdown]
# ### Analysis Question 11:** The company has decided to give 20% discount vouchers to the top 3 most frequent customers. Find the IDs of these customers and the number of orders they placed.

# %%
df['customer_id'].value_counts().head(3)

# %% [markdown]
# #### Observations:
# The top 3 most frequent customers are 52832, 47440, and 83287, who placed 13, 10, and 9 orders respectively. These customers are good candidates for receiving discount vouchers as they represent loyal and high-frequency users.

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# ### Analysis Question 12**: Perform a multivariate analysis to explore relationships between the important variables in the dataset. (It is a good idea to explore relations between numerical variables as well as relations between numerical and categorical variables)

# %% [markdown]
# Relationship between numerical variables (Correlation)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

numeric_df = df[['cost_of_the_order', 'food_preparation_time', 'delivery_time']]

sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')

plt.title('Correlation between Numerical Variables')

plt.savefig("graph_correlation.jpg", bbox_inches='tight')

plt.show()

# %% [markdown]
# Observations:
#
# The correlation heatmap shows the relationship between cost of the order, food preparation time, and delivery time. There appears to be weak correlations among these variables, suggesting that order cost does not strongly influence preparation or delivery time.

# %% [markdown]
# Relationship between cuisine and cost

# %%
plt.figure(figsize=(12, 6))

sns.boxplot(data=df, x='cuisine_type', y='cost_of_the_order')

plt.xticks(rotation=45)

plt.title('Order Cost Distribution by Cuisine Type')

plt.savefig("graph_cuisine_cost.jpg", bbox_inches='tight')

plt.show()

# %% [markdown]
# Observations:
#
# The boxplot shows how the order cost varies accross different cuisine types. Some cuisines tend to have higher order costs than others, indicating differences in pricing or portion sizes.

# %% [markdown]
# Relationship between weekends and delivery times

# %%
plt.figure(figsize=(8, 6))

sns.boxplot(data=df, x='day_of_the_week', y='delivery_time')

plt.title('Delivery Time on Weekdays vs Weekends')

plt.savefig("graph_delivery_time_weekdays.jpg", bbox_inches='tight')

plt.show()

# %% [markdown]
# Observations:
#
# The delivery time distribution appears slightly different between weekdays and weekends. This indicate higher demand or traffic conditions affecting delivery efficiency.

# %% [markdown]
# Relationship between rating and delivery time

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd # Import pandas
from google.colab import drive # Import drive
# drive.mount('/content/drive')  # Optional for Colab # Mount Google Drive
path='data/' # Define path
df=pd.read_csv(path + 'foodhub_order.csv') # Load DataFrame

plt.figure(figsize=(8,5))
sns.boxplot(x='rating', y='delivery_time', data=df)
plt.title('Delivery Time by Rating')
plt.savefig("graph_delivery_time_rating.jpg", bbox_inches='tight')
plt.show()

# %% [markdown]
# Observations:
#
# Orders with faster delivery times tend to receive slightly higher ratings, suggesting that delivery speed may influence customer satisfaction.

# %% [markdown]
# ### Conclusion
# The multivariate analysis highlihts several relationship in the dataset. While numerical variables such as cost, preparation time, and delivery time show weak correlations, categorical comparisons reveal useful insights. Delivery time may influence customer ratings, and order costs vary accross cuisine types. These insights can help FoodHub optimize delivery operations and understand customer preferences.

# %% [markdown]
# ### Analysis Question 13:** The company wants to provide a promotional offer in the advertisement of the restaurants. The condition to get the offer is that the restaurants must have a rating count of more than 50 and the average rating should be greater than 4. Find the restaurants fulfilling the criteria to get the promotional offer.

# %%
# Keep only rows where rating is given
rated_df = df[df['rating'] != 'Not given'].copy()

# Convert rating to numeric
rated_df['rating'] = rated_df['rating'].astype(int)

# Group by restaurant and calculate rating count and average rating
restaurant_ratings = rated_df.groupby('restaurant_name')['rating'].agg(['count', 'mean'])

# Filter restaurants meeting the criteria
promo_restaurants = restaurant_ratings[(restaurant_ratings['count'] > 50) & (restaurant_ratings['mean'] > 4)]

promo_restaurants

# %% [markdown]
# #### Observations:
# Since the rating column contains the text value "Not given", it must first be filtered out before calculating the average rating. After converting the remaining ratings to numeric format, restaurants with more thant 50 ratings and an average rating above 4 can be identified for the promotional offer. These restaurants demonstrate both high customer engagement and strong customer satisfaction, making them good candidates for promotional advertising.

# %% [markdown]
# ### Analysis Question 14:** The company charges the restaurant 25% on the orders having cost greater than 20 dollars and 15% on the orders having cost greater than 5 dollars. Find the net revenue generated by the company across all orders.

# %%
# Function to calculate revenue per order
def calculate_revenue(cost):

  if cost > 20:
    return cost * 0.25

  elif cost > 5:
    return cost * 0.15

  else:
    return 0

# Apply the function to the dataset
df['revenue'] = df['cost_of_the_order'].apply(calculate_revenue)

# Total revenue
total_revenue = df['revenue'].sum()

total_revenue

# %% [markdown]
# #### Observations:
# Based on the commission structure applied to each order, the total net revenue generated by the company accross all orders is approximately $6166.

# %% [markdown]
# ### Analysis Question 15:** The company wants to analyze the total time required to deliver the food. What percentage of orders take more than 60 minutes to get delivered from the time the order is placed? (The food has to be prepared and then delivered.)

# %%
# Calculate  total time from order to delivery
df['total_time'] = df['delivery_time'] + df['food_preparation_time']

# Count orders taking more than 60 minutes
orders_above_60 = df[df['total_time'] > 60].shape[0]

# Total number of orders
total_orders = df.shape[0]

# Percentage
Percentage_above_60 = (orders_above_60 / total_orders) * 100

Percentage_above_60

# %% [markdown]
# #### Observations:
# Approximately 10.5% of the orders take more than 60 minutes from the time the order is placed until delivery. This suggests that most deliveries are completed within an hour, though a small proportion of orders experience longer preparation and delivery times.

# %% [markdown]
# ### Analysis Question 16:** The company wants to analyze the delivery time of the orders on weekdays and weekends. How does the mean delivery time vary during weekdays and weekends?

# %%
df.groupby('day_of_the_week')['delivery_time'].mean()

# %% [markdown]
# #### Observations:
# The mean delivery time is higher on weekdays compared to weekends. This may be due to heavier traffic conditions or higher operational load during working days. On weekends, deliveries tend to be slightly faster.

# %% [markdown]
# ### Conclusion and Recommendations

# %% [markdown]
# ### Analysis Question 17:** What are your conclusions from the analysis? What recommendations would you like to share to help improve the business? (You can use cuisine type and feedback ratings to drive your business recommendations.)

# %% [markdown]
# ### Conclusions:
# * The analysis shows that a small number of restaurants receive a large proportion of the orders, indicating strong customer preferences for certain brands.
# * American cuisine is the most popular cuisine, especially during weekends, suggesting that customers prefer familiar and comfort food when ordering online.
# * The average delivery time is around 24 minutes, and most orders are delivered within one hour, although around 10% of the orders take more than 60 minutes.
# * Delivery times tend to be slightly higher during weekdays compared to weekends, which may be due to traffic conditions or higher operational load.
# * Orders with higher costs contribute more significantly to the company's revenue, particularly those above $20 due to the higher commission rate.
# * Customer ratings tend to be higher when delivery times are shorter, indicating that delivery efficiency plays an important role in customer satisfaction.

# %% [markdown]
# ### Recommendations:
#
# * Promote highly rated restaurants with strong customer engagement. Restaurants that maintain high ratings and receive many reviews should be highlighted in promotional campaigns.
# * Focus marketing efforts on popular cuisines, especially American cuisine, which appear to generate strong demand.
# * Encourage high-value orders through promotions, combo meals, or bundle offers since orders above $20 generate higher commission revenue.
# * Improve delivery efficiency, especially for orders that take longer than 60 minutes. This could involve optimizing delivery routes or increasing the number of delivery personnel during peak hours.
# * Monitor restaurant preparation times to identify restaurants that slow down the overall delivery process and provide support or guidelines to improve thier efficiency.
# * Reward loyal customers through targeted promotions or discount vouchers, as frequent customers represent a valuable and stable source of revenue.

# %% [markdown]
# ---

# %%
# !pip install nbconvert

# %%
# This cell was used during development and is not required for the portfolio version.

# %%
# !ls
